# %%
import pandas as pd
from sentence_transformers import SentenceTransformer

# %% [markdown]
# I will use a simple sentence transformer to create the embeddings, and then feed the embeddings into a simple multi output classifier/

# %%
df = pd.read_json("data/dataset.json")
df[:50]

# I decided to shuffle the dataframe to ensure randomness in the 50 50 train-test split, however when I tried this approach
#  without shuffling the accuracy was 0 as the test split had label that werent present in the train split.

#df = df.sample(frac=1).reset_index(drop=True)
# Out:
#                                               summary  \
# 0   Issue reported: Search bar expands unexpectedl...
# 1   Detected anomaly: AI Assistant Icon Color Miss...
# 2   User noticed: Preserve table filtering after n...
# 3   Issue reported: Containers crash with Failed t...
# 4   System shows: Inconsistent inlay hints for fun...
# 5   Issue reported: Context menu action Disable fo...
# 6   System shows: False positive in IncorrectCance...
# 7   Detected anomaly: High CPU Usage and Cache Reb...
# 8   Problem observed: Add Mark as relates to (and/...
# 9   Improvement needed: AI duplicate detection inc...
# 10  Issue reported: IDE Freezes with Blank Whats N...
# 11  Detected anomaly: UI Improvement Suggestion fo...
# 12  Issue reported: Bad visual feedback on selecte...
# 13  Issue reported: Error saving issue description...
# 14  User noticed: Rename AppCode module configurat...
# 15  Improvement needed: Xcode file generation trig...
# 16  User noticed: Enable parallel Gradle model fet...
# 17  Detected anomaly: Improve Kotlin Multiplatform...
# 18  Detected anomaly: Issue with resource loading ...
# 19  Issue reported: Support adding repositories to...
# 20  Improvement needed: Clarify compiler behavior ...
# 21  Problem observed: Add support for custom sshd_...
# 22  System shows: Native: partial linkage warnings...
# 23  Issue reported: Optimize performance for linke...
# 24  System shows: Recurring KaBaseIllegalPsiExcept...
# 25  Improvement needed: Improve positioning of sho...
# 26  Detected anomaly: Remove location labels next ...
# 27  Improvement needed: Investigate multiple excep...
# 28  Improvement needed: Fix flaky update test in T...
# 29  Improvement needed: Island Dark Theme: Inconsi...
# 30  User noticed: Inconsistent drag-and-drop file ...
# 31  User noticed: Structure view incorrectly shows...
# 32  System shows: Add Ask AI About the Stack Trace...
# 33  System shows: Settings tab: Improve clarity of...
# 34  Problem observed: Adjust chat text size accord...
# 35  Detected anomaly: Issues with SUBPLOTS_SPEC ha...
# 36  Detected anomaly: FileAlreadyExistsException d...
# 37  User noticed: Missing backend syntax highlight...
# 38  Improvement needed: Enhance root node log outp...
# 39  Improvement needed: Suggestion appears on the ...
# 40  System shows: Structure tool window displays m...
# 41  System shows: Plugin requirement notification ...
# 42  Improvement needed: Duplicated Kotlin Notebook...
# 43  Issue reported: Last symbol dropped when apply...
# 44  System shows: Review and improve Docker image ...
# 45  Improvement needed: Misplaced button in Summar...
# 46  Problem observed: Exception due to invalid Tex...
# 47  Unexpected behavior: KPP plugin causes configu...
# 48  Problem observed: Improve the quality of the g...
# 49  Unexpected behavior: Support Create Class quic...
#
#                                           description reporter_name  \
# 0   Details provided:\n**Problem:** The search bar...      user_079
# 1   Observed behaviour:\nThe AI Assistant menu ite...      user_062
# 2   Description:\n**Problem:**\nCurrently, when a ...      user_134
# 3   Observed behaviour:\nWhen running six containe...      user_105
# 4   Summary of issue:\nThere is an inconsistency i...      user_078
# 5   Summary of issue:\nThe 'Disable for This Proje...      user_113
# 6   Observed behaviour:\nThe `IncorrectCancellatio...      user_120
# 7   Observed behaviour:\nAfter updating the projec...      user_127
# 8   Reported case:\nCurrently, the system suggests...      user_079
# 9   Observed behaviour:\nThere is an issue with th...      user_081
# 10  Details provided:\nOccasionally, opening the "...      user_127
# 11  Details provided:\nThe preflight checks UI dis...      user_084
# 12  Observed behaviour:\nWhen using project depend...      user_060
# 13  Reported case:\nWhen attempting to save the de...      user_081
# 14  Description:\n[!](Screenshot%202025-06-06%20at...      user_097
# 15  Observed behaviour:\nThe plugin currently trig...      user_097
# 16  Description:\nThe setting 'Enable parallel Gra...      user_136
# 17  Description:\nThe current behavior of the Kotl...      user_097
# 18  Observed behaviour:\nWhen using Jewel bundled ...      user_074
# 19  Reported case:\n## Status Quo\n\nCurrently, it...      user_115
# 20  Details provided:\nThe `runBlocking` function ...      user_017
# 21  Summary of issue:\n## Status Quo\n\nCurrently,...      user_115
# 22  Summary of issue:\n**Problem:**\nWhen using th...      user_122
# 23  Reported case:\n### Problem Description\nAfter...      user_019
# 24  Details provided:\nAn error occurs repeatedly ...      user_017
# 25  Summary of issue:\nCurrent behavior positions ...      user_002
# 26  Details provided:\nThe KMP plugin adds locatio...      user_097
# 27  Details provided:\n**Summary:**\n\nThere are f...      user_091
# 28  Observed behaviour:\nThe test `ToolsInstallati...      user_020
# 29  Summary of issue:\n**Steps to reproduce:**\n\n...      user_054
# 30  Summary of issue:\nCurrently, the IDE exhibits...      user_116
# 31  Description:\nThe structure view in the IDE di...      user_072
# 32  Observed behaviour:\nCurrently, users can copy...      user_003
# 33  Observed behaviour:\nThere are two search fiel...      user_054
# 34  Observed behaviour:\nThe current chat text siz...      user_079
# 35  Reported case:\nProblems have been identified ...      user_060
# 36  Summary of issue:\nThe Native pre-commit build...      user_136
# 37  Observed behaviour:\nIn version 252 `.cpp` fil...      user_069
# 38  Reported case:\nCurrently, the root node in th...      user_028
# 39  Summary of issue:\n**Problem:**\nThe suggestio...      user_108
# 40  Observed behaviour:\nThe Structure tool window...      user_064
# 41  Description:\nThere is an issue with the notif...      user_098
# 42  Reported case:\nThe Kotlin Notebook (KN) secti...      user_060
# 43  Observed behaviour:\nThere is an issue where t...      user_080
# 44  Reported case:\nThe recent change to Docker im...      user_105
# 45  Description:\nThere is a UI glitch in the "Sum...      user_079
# 46  Description:\nAn exception occurs intermittent...      user_108
# 47  Details provided:\nThe project build fails aft...      user_136
# 48  Summary of issue:\nThere is an issue with the ...      user_065
# 49  Observed behaviour:\n**Summary:**\n\nWe should...      user_091
#
#              project_name  Assignee  Priority                 Type  id
# 0        Unidentified Roe  user_128    Normal                  Bug   1
# 1        Unidentified Roe  user_018    Normal                 Task   2
# 2            Fast Buffalo      None    Normal                  Bug   3
# 3   Unidentified Hedgehog  user_126     Major                  Bug   4
# 4              Lazy Whale  user_056    Normal                  Bug   5
# 5             Lazy Beaver  user_113    Normal                  Bug   6
# 6             Fast Badger  user_070    Normal                  Bug   7
# 7      Unidentified Tiger  user_048    Normal                  Bug   8
# 8        Unidentified Roe  user_045    Normal    Usability problem   9
# 9        Unidentified Roe  user_081    Normal                  Bug  10
# 10     Unidentified Tiger  user_063  Critical                  Bug  11
# 11               Fast Roe  user_077     Minor                  Bug  12
# 12              Fast Wolf      None    Normal                  Bug  13
# 13       Unidentified Roe  user_114    Normal                  Bug  14
# 14               Fast Roe  user_066    Normal                 Task  15
# 15               Fast Roe  user_053    Normal                 Task  16
# 16             Fast Tiger  user_119    Normal                  Bug  17
# 17               Fast Roe  user_077    Normal                 Task  18
# 18          Fast Hedgehog  user_074  Critical                  Bug  19
# 19             Lazy Panda  user_009    Normal              Feature  20
# 20             Fast Panda      None    Normal                  Bug  21
# 21             Lazy Panda  user_009    Normal                 Task  22
# 22            Fast Falcon      None    Normal                  Bug  23
# 23       Unidentified Roe  user_019     Major  Performance problem  24
# 24             Fast Panda  user_017    Normal                  Bug  25
# 25            Lazy Beaver  user_071    Normal                  Bug  26
# 26               Fast Roe  user_006     Major                  Bug  27
# 27              Fast Wolf  user_060  Critical            Exception  28
# 28     Unidentified Whale  user_020    Normal                 Task  29
# 29            Fast Badger  user_103    Normal            Cosmetics  30
# 30            Fast Badger  user_093     Major    Usability Problem  31
# 31             Fast Panda  user_132    Normal                  Bug  32
# 32           Fast Buffalo      None     Minor              Feature  33
# 33            Fast Badger  user_083    Normal    Usability Problem  34
# 34       Unidentified Roe  user_018    Normal                 Task  35
# 35              Fast Wolf      None    Normal              Feature  36
# 36            Fast Falcon  user_092    Normal                  Bug  37
# 37     Unidentified Tiger  user_056     Major                  Bug  38
# 38           Lazy Raccoon      None    Normal                  Bug  39
# 39            Lazy Beaver  user_071     Minor                 Task  40
# 40     Unidentified Tiger  user_064    Normal    Usability Problem  41
# 41            Fast Badger  user_137    Normal                  Bug  42
# 42              Fast Wolf      None    Normal                  Bug  43
# 43       Unidentified Roe  user_018    Normal                  Bug  44
# 44  Unidentified Hedgehog      None    Normal                  Bug  45
# 45       Unidentified Roe  user_018    Normal            Cosmetics  46
# 46            Lazy Beaver  user_108    Normal                  Bug  47
# 47            Fast Falcon      None        P4                  Bug  48
# 48            Fast Badger  user_116    Normal            Cosmetics  49
# 49              Fast Wolf  user_025    Normal                  Bug  50

# %% [markdown]
# I decided to use a LabelEncoder while at it, for this simple case we can also just do list(set(labels)) and enumarete.

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder

type_encoder = LabelEncoder()
priority_encoder = LabelEncoder()
project_encoder = LabelEncoder()

type_labels = type_encoder.fit_transform(df["Type"][:50])
priority_labels = priority_encoder.fit_transform(df["Priority"][:50])
project_labels = project_encoder.fit_transform(df["project_name"][:50])

df["type_enc"] = -1
df["priority_enc"] = -1
df["project_enc"] = -1

df.loc[:49, "type_enc"] = type_encoder.transform(df["Type"][:50])
df.loc[:49, "priority_enc"] = priority_encoder.transform(df["Priority"][:50])
df.loc[:49, "project_enc"] = project_encoder.transform(df["project_name"][:50])

print(type_encoder.classes_,
priority_encoder.classes_,
project_encoder.classes_)
# Out:
# ['Bug' 'Cosmetics' 'Exception' 'Feature' 'Performance problem' 'Task'
#  'Usability Problem' 'Usability problem'] ['Critical' 'Major' 'Minor' 'Normal' 'P4'] ['Fast Badger' 'Fast Buffalo' 'Fast Falcon' 'Fast Hedgehog' 'Fast Panda'
#  'Fast Roe' 'Fast Tiger' 'Fast Wolf' 'Lazy Beaver' 'Lazy Panda'
#  'Lazy Raccoon' 'Lazy Whale' 'Unidentified Hedgehog' 'Unidentified Roe'
#  'Unidentified Tiger' 'Unidentified Whale']

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
df['embeddings'] = df.apply(lambda row: embedding_model.encode(f"{row['summary']} {row['description']}"), axis=1)

# %%
x_train = np.vstack(df['embeddings'].values[:50])
y_train = df[["type_enc", "priority_enc", "project_enc"]].values[:50]

x_test = np.vstack(df['embeddings'].values[50:])


x_train.shape, y_train.shape, x_test.shape
# Out:
# ((50, 384), (50, 3), (50, 384))

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.linear_model import LogisticRegression

classifier = MultiOutputClassifier(LogisticRegression(class_weight='balanced'))
classifier.fit(x_train, y_train)

predictions = classifier.predict(x_test)

# %% [markdown]
# # UPDATE
# For Deliverable 2 -> filling the dataset with the predicted values. The Dataset can be found in the data folder as dataset_filled.json

# %%
df = pd.read_json("data/dataset.json")

predictions_to_labels = lambda preds: (type_encoder.inverse_transform([preds[0]])[0],
                                       priority_encoder.inverse_transform([preds[1]])[0],
                                        project_encoder.inverse_transform([preds[2]])[0])
predictions = [predictions_to_labels(pred) for pred in predictions]

df.loc[50:, ['Type', 'Priority', 'project_name']] = predictions
df[50:100]
# Out:
#                                               summary  \
# 50  Issue reported: java.lang.NoSuchMethodError: o...
# 51  Issue reported: Fix bash script formating issu...
# 52  Problem observed: Authorization Issue with Sum...
# 53  User noticed: Regression: Unfriendly error whe...
# 54  System shows: Improve project selection for su...
# 55  System shows: Disable Setting value is redunda...
# 56  System shows: Java imports are unresolved in B...
# 57  Issue reported: Buildifier does not reformat f...
# 58  Improvement needed: Redundant .Companion is in...
# 59  Unexpected behavior: Enhance project switching...
# 60  System shows: Implement Recent Assignee Sugges...
# 61  Detected anomaly: "Update usages to reflect si...
# 62  Improvement needed: Clarify Git branching stra...
# 63  User noticed: IDE hangs during the creation of...
# 64  Detected anomaly: AI Mentions user themselves ...
# 65  Detected anomaly: Add ability to build other p...
# 66  Detected anomaly: Exclude certain .star files ...
# 67  Issue reported: Background images cause persis...
# 68  Problem observed: DataWrangler: excessive expo...
# 69  Problem observed: Support for single file in m...
# 70  Improvement needed: Add descriptions for proje...
# 71  Improvement needed: Clarification and handling...
# 72  Problem observed: Issue with default tab for t...
# 73  User noticed: UI Freeze Issue in EditSearchRep...
# 74  Issue reported: Rename AppCode module configur...
# 75  Problem observed: Structure view incorrectly s...
# 76  Problem observed: Error saving issue descripti...
# 77  Issue reported: UI Improvement Suggestion for ...
# 78  User noticed: Inconsistent inlay hints for fun...
# 79  Issue reported: Investigate multiple exception...
# 80  Issue reported: Containers crash with Failed t...
# 81  Improvement needed: Support for single file in...
# 82  Issue reported: Buildifier does not reformat f...
# 83  System shows: Search bar expands unexpectedly ...
# 84  Issue reported: Last symbol dropped when apply...
# 85  Problem observed: Investigate multiple excepti...
# 86  Unexpected behavior: UI Improvement Suggestion...
# 87  Detected anomaly: Misplaced button in Summariz...
# 88  System shows: Settings tab: Improve clarity of...
# 89  User noticed: DataWrangler: excessive export o...
# 90  Problem observed: IDE Freezes with Blank Whats...
# 91  User noticed: Exception due to invalid TextRan...
# 92  System shows: Add Mark as relates to (and/or o...
# 93  Issue reported: Missing backend syntax highlig...
# 94  Issue reported: Bad visual feedback on selecte...
# 95  Detected anomaly: Redundant .Companion is inse...
# 96  Detected anomaly: Clarify compiler behavior fo...
# 97  Unexpected behavior: Remove location labels ne...
# 98  Issue reported: AI duplicate detection include...
# 99  Detected anomaly: DataWrangler: excessive expo...
#
#                                           description reporter_name  \
# 50  Summary of issue:\n**Version:** Build #IU-251....      user_091
# 51  Description:\nRemove bash script formating fro...      user_028
# 52  Summary of issue:\nThe 'SummarizeT' Slack app ...      user_130
# 53  Details provided:\nWhen attempting to `Create ...      user_050
# 54  Summary of issue:\nThe current 'summarizeT' fu...      user_081
# 55  Description:\nThe diagnostic "Setting value is...      user_121
# 56  Reported case:\nObserved behavior:\n\n* Java i...      user_028
# 57  Details provided:\nThe `buildifier` tool does ...      user_028
# 58  Reported case:\nAfter invoking the "Move" refa...      user_072
# 59  Description:\n**Problem:**\n\n* Previously, sw...      user_079
# 60  Description:\nCurrently, assigning reviewers o...      user_027
# 61  Reported case:\nThe 'Update usages to reflect ...      user_072
# 62  Reported case:\nThe current state of the Git b...      user_133
# 63  Observed behaviour:\nThe IntelliJ IDEA hangs w...      user_060
# 64  Observed behaviour:\nThe AI feature integrated...      user_081
# 65  Description:\n**Problem:** Currently, building...      user_101
# 66  Summary of issue:\nThere is an issue with Qoda...      user_028
# 67  Reported case:\n**Issue:**\nUsers have consist...      user_044
# 68  Observed behaviour:\nobserved on\nDataSpell 20...      user_038
# 69  Description:\ne.g. if one file is used as a de...      user_010
# 70  Reported case:\nThere are suggestions to impro...      user_034
# 71  Reported case:\n**Problem:** A user encounters...      user_051
# 72  Summary of issue:\n### Problem Description\n\n...      user_051
# 73  Summary of issue:\nThere is a reported **UI fr...      user_051
# 74  Summary of issue:\nAuto-generated issue based ...          None
# 75  Observed behaviour:\nAuto-generated issue base...          None
# 76  Description:\nAuto-generated issue based on an...          None
# 77  Observed behaviour:\nAuto-generated issue base...          None
# 78  Details provided:\nAuto-generated issue based ...          None
# 79  Description:\nAuto-generated issue based on an...          None
# 80  Description:\nAuto-generated issue based on an...          None
# 81  Details provided:\nAuto-generated issue based ...          None
# 82  Details provided:\nAuto-generated issue based ...          None
# 83  Details provided:\nAuto-generated issue based ...          None
# 84  Summary of issue:\nAuto-generated issue based ...          None
# 85  Details provided:\nAuto-generated issue based ...          None
# 86  Details provided:\nAuto-generated issue based ...          None
# 87  Details provided:\nAuto-generated issue based ...          None
# 88  Summary of issue:\nAuto-generated issue based ...          None
# 89  Summary of issue:\nAuto-generated issue based ...          None
# 90  Details provided:\nAuto-generated issue based ...          None
# 91  Observed behaviour:\nAuto-generated issue base...          None
# 92  Summary of issue:\nAuto-generated issue based ...          None
# 93  Reported case:\nAuto-generated issue based on ...          None
# 94  Description:\nAuto-generated issue based on an...          None
# 95  Reported case:\nAuto-generated issue based on ...          None
# 96  Reported case:\nAuto-generated issue based on ...          None
# 97  Details provided:\nAuto-generated issue based ...          None
# 98  Summary of issue:\nAuto-generated issue based ...          None
# 99  Description:\nAuto-generated issue based on an...          None
#
#              project_name  Assignee  Priority               Type   id
# 50            Fast Falcon      None  Critical                Bug   51
# 51           Lazy Raccoon  user_028    Normal               Task   52
# 52            Lazy Beaver  user_124     Minor               Task   53
# 53            Fast Falcon  user_001    Normal               Task   54
# 54       Unidentified Roe  user_124     Minor                Bug   55
# 55             Lazy Panda  user_121    Normal               Task   56
# 56            Fast Falcon      None    Normal                Bug   57
# 57               Fast Roe  user_076    Normal               Task   58
# 58              Fast Wolf  user_107    Normal                Bug   59
# 59       Unidentified Roe  user_040    Normal  Usability Problem   60
# 60           Fast Buffalo  user_027    Normal            Feature   61
# 61            Lazy Beaver  user_017    Normal                Bug   62
# 62           Lazy Raccoon  user_133    Normal               Task   63
# 63              Fast Wolf      None  Critical          Exception   64
# 64       Unidentified Roe  user_081     Minor                Bug   65
# 65               Fast Roe  user_090    Normal               Task   66
# 66            Fast Falcon  user_028    Normal                Bug   67
# 67     Unidentified Tiger  user_044     Major                Bug   68
# 68               Fast Roe  user_104    Normal               Task   69
# 69            Fast Falcon      None    Normal                Bug   70
# 70               Fast Roe  user_096     Major          Cosmetics   71
# 71  Unidentified Hedgehog  user_058    Normal                Bug   72
# 72       Unidentified Roe  user_051    Normal                Bug   73
# 73            Lazy Beaver      None    Normal                Bug   74
# 74               Fast Roe      None    Normal               Task   75
# 75             Fast Panda      None    Normal                Bug   76
# 76       Unidentified Roe      None    Normal                Bug   77
# 77               Fast Roe      None     Minor               Task   78
# 78             Lazy Whale      None    Normal                Bug   79
# 79             Fast Panda      None  Critical          Exception   80
# 80  Unidentified Hedgehog      None     Major                Bug   81
# 81            Fast Falcon      None    Normal                Bug   82
# 82               Fast Roe      None    Normal               Task   83
# 83       Unidentified Roe      None    Normal                Bug   84
# 84       Unidentified Roe      None     Minor                Bug   85
# 85            Fast Falcon      None  Critical          Exception   86
# 86               Fast Roe      None     Minor               Task   87
# 87       Unidentified Roe      None     Minor          Cosmetics   88
# 88            Fast Badger      None    Normal  Usability Problem   89
# 89               Fast Roe      None    Normal               Task   90
# 90     Unidentified Tiger      None  Critical                Bug   91
# 91            Lazy Beaver      None    Normal                Bug   92
# 92       Unidentified Roe      None    Normal  Usability problem   93
# 93     Unidentified Tiger      None     Major                Bug   94
# 94               Fast Roe      None     Major                Bug   95
# 95       Unidentified Roe      None    Normal                Bug   96
# 96             Fast Panda      None    Normal                Bug   97
# 97               Fast Roe      None     Major                Bug   98
# 98       Unidentified Roe      None    Normal                Bug   99
# 99               Fast Roe      None     Major               Task  100

# %%
df.to_json("data/dataset_filled.json", orient="records", indent=4)
